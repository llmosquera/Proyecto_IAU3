# %%
from google.colab import drive
drive.mount('/content/MyDrive')
# Out:
# Mounted at /content/MyDrive

# %%
files = ('/content/MyDrive/MyDrive/Ai Espe/Data/Faces/PROYECTOIA-U3')

# %%
import glob
extenciones = ('jpeg','png','jpg')

lista_de_imagenes = []
for i in extenciones:
  ubicacion = f"/content/MyDrive/MyDrive/Ai Espe/Data/Faces/PROYECTOIA-U3/*/*.{i}"
  rutas = glob.glob(ubicacion)
  lista_de_imagenes.append(rutas)
print(lista_de_imagenes)
# Out:
# [['/content/MyDrive/MyDrive/Ai Espe/Data/Faces/PROYECTOIA-U3/GoyesAnthony/L00393010_2.jpeg', '/content/MyDrive/MyDrive/Ai Espe/Data/Faces/PROYECTOIA-U3/GoyesAnthony/L00393010_1.jpeg', '/content/MyDrive/MyDrive/Ai Espe/Data/Faces/PROYECTOIA-U3/GoyesAnthony/L00393010_3.jpeg', '/content/MyDrive/MyDrive/Ai Espe/Data/Faces/PROYECTOIA-U3/MelanyLópez/L00392999_3.jpeg', '/content/MyDrive/MyDrive/Ai Espe/Data/Faces/PROYECTOIA-U3/MelanyLópez/L00392999_1.jpeg', '/content/MyDrive/MyDrive/Ai Espe/Data/Faces/PROYECTOIA-U3/MelanyLópez/L00392999_2.jpeg', '/content/MyDrive/MyDrive/Ai Espe/Data/Faces/PROYECTOIA-U3/Jorge Borrero/L00379412_3.jpeg', '/content/MyDrive/MyDrive/Ai Espe/Data/Faces/PROYECTOIA-U3/Jorge Borrero/L00379412_1.jpeg', '/content/MyDrive/MyDrive/Ai Espe/Data/Faces/PROYECTOIA-U3/Jorge Borrero/L00379412_2.jpeg', '/content/MyDrive/MyDrive/Ai Espe/Data/Faces/PROYECTOIA-U3/Nataly Acosta/Perfil Izquierdo.jpeg', '/content/MyDrive/MyDrive/Ai Espe/Data/Faces/PROYECTOIA-U3/Nataly Acosta/Perfil 
# ...

# %%
import os 
labels = os.listdir('/content/MyDrive/MyDrive/Ai Espe/Data/Faces/PROYECTOIA-U3')

data_set = []
for Y_rut in labels:
  path = f'/content/MyDrive/MyDrive/Ai Espe/Data/Faces/PROYECTOIA-U3/{Y_rut}'
  X_rut = os.listdir(path)
  for i in X_rut:
    T = f'{path}/{i}'
    data_set.append([T,Y_rut])

# %%
from keras.preprocessing.image import ImageDataGenerator, load_img,image, img_to_array

# %%
#generador de datos 
train_datagen = ImageDataGenerator(
                    rotation_range=30,
                    zoom_range=0.3,
                    width_shift_range=0.4,
                    height_shift_range=0.4,
                    horizontal_flip=False,
                    vertical_flip=True)

width, height = 192,192

for i in range(len(data_set)):
  rute = data_set[i][0]
  etiqueta = data_set[i][0]
  imagen = load_img(rute)
  imge=cv2.resize(image.img_to_array(imgen), (width_shape, height_shape), interpolation = cv2.INTER_AREA)

# %%
import os
import numpy as np
import cv2
from keras.preprocessing.image import ImageDataGenerator, load_img,image, img_to_array
DG_folder='/content/MyDrive/MyDrive/Ai Espe/Data/Faces/New_data'
images_increased = 6 # cantidad d eaumento de  datos 6 imagens por cada foto  

try:
  os.mkdir(DG_folder)
except:
  print("")
# creo el generador de datos y entablesco las  diferentes transformaciones para las imagnes 
train_datagen = ImageDataGenerator(
                    rotation_range=30,
                    zoom_range=0.3,
                    width_shift_range=0.4,
                    height_shift_range=0.4,
                    horizontal_flip=True,
                    vertical_flip=True)
data_path = "/content/MyDrive/MyDrive/Ai Espe/Data/Faces/PROYECTOIA-U3"
data_dir_list = os.listdir(data_path)
width_shape, height_shape = 512,512
i=0
num_images=0
for image_file in data_dir_list:
    img_list=os.listdir(data_path)
    img_path =  data_path + '/'+ image_file
    os.mkdir(DG_folder+'/'+image_file)
    for file in os.listdir(img_path):
      img_pat= (img_path+'/'+file )
      imge=load_img(img_pat)
      imge=cv2.resize(image.img_to_array(imge), (width_shape, height_shape), interpolation = cv2.INTER_AREA)
      x= imge/255
      x=np.expand_dims(x,axis=0)
      t=1
      for output_batch in train_datagen.flow(x,batch_size=1):
          a=image.img_to_array(output_batch[0])
          imagen=output_batch[0,:,:]*255
          imgfinal = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)
          
          cv2.imwrite(DG_folder+'/'+image_file+"/%i%i.jpg"%(i,t), imgfinal) 
          t+=1
          
          num_images+=1
          if t>images_increased:
              break
      i+=1    
print("images generated",num_images)
# Out:
# images generated 468

# %%
# carpeta donde  se van a guardar las nuevas imagenes 
DG_folder='/content/MyDrive/MyDrive/Ai Espe/Data/Faces/New_data'

# %%
#Agregamos la ruta general 
os.chdir("/content/MyDrive/MyDrive/Ai Espe/Data/Faces/Aumentada")
#Agregamos la ruta BananaAumented
images_path = "/content/MyDrive/MyDrive/Ai Espe/Data/Faces/Aumenta"
class_names = os.listdir(images_path)
class_names.sort()
print(class_names)
# Out:
# ['Ariel Chabla', 'ArroboMercy', 'BarraganSteven', 'CevallosJoan', 'EnriquezSelena', 'GenesisHeredia', 'GoyesAnthony', 'Hector Cedeño', 'Jhon Zambrano', 'Jordan Espinosa', 'Jorge Borrero', 'JoseRuiz', 'LeonardoBorja', 'LucioCarlos', 'MasacheFernando', 'MelanyLópez', 'MosqueraLucy', 'Nataly Acosta', 'OlallaLuis', 'PauteKevin', 'PárragaMaríaJosé', 'Raymond Dávila', 'RivasSelena', 'SalazarJohana', 'Solano Wilmer', 'SolórzanoBryan', 'rembg']

# %%
import  cv2
# reduccion del ruido  en las imagene 
for class_name in class_names:
    cur_path = images_path + "/" + class_name
    cur_label = class_name
    i = 1
    os.mkdir('/content/MyDrive/MyDrive/Ai Espe/Data/Faces/Sin_ruido/'+ cur_label)
    
    for file in glob.glob(cur_path + "/*"):
        print("Processing Image - {} in {}".format(i, cur_label))
        
        # leer la ruta de las imágenes
        image = cv2.imread(file)
        # denotación de imágenes
        dst = cv2.fastNlMeansDenoisingColored(image,None,10,10,7,21)
        b,g,r = cv2.split(dst)
        rgb_dst = cv2.merge([r,g,b])
        # guardamos las imagenes

        save_path = '/content/MyDrive/MyDrive/Ai Espe/Data/Faces/Sin_ruido/'+ cur_label
        cv2.imwrite((save_path +'/' + cur_label + str(i)+ '.jpg'),
                    cv2.cvtColor(rgb_dst,cv2.COLOR_RGB2BGR))
        i+=1

# %%
# remover  fondo 
# coloco la ruta d ela imagenes sin ruido 
images_path = '/content/MyDrive/MyDrive/Ai Espe/Data/Faces/Sin_ruido/'
class_names = os.listdir(images_path)
class_names.sort()
print(class_names)
# Out:
# ['Ariel Chabla', 'ArroboMercy', 'BarraganSteven', 'CevallosJoan', 'EnriquezSelena', 'GenesisHeredia', 'GoyesAnthony', 'Hector Cedeño', 'Jhon Zambrano', 'Jordan Espinosa', 'Jorge Borrero', 'JoseRuiz', 'LeonardoBorja', 'LucioCarlos', 'MasacheFernando', 'MelanyLópez', 'MosqueraLucy', 'Nataly Acosta', 'OlallaLuis', 'PauteKevin', 'PárragaMaríaJosé', 'Raymond Dávila', 'RivasSelena', 'SalazarJohana', 'Solano Wilmer', 'SolórzanoBryan']

# %% [markdown]
# # Nueva sección

# %%
#  funcion para  remover la imagnes que se encunetra de las carpetas de sin ruido 
import  cv2
for class_name in class_names:
    cur_path = images_path + "/" + class_name
    cur_label = class_name
    i = 1
    os.mkdir('/content/MyDrive/MyDrive/Ai Espe/Data/Faces/Sin_Fondo/'+ cur_label)
    
    for file in glob.glob(cur_path + "/*"):
        print("Processing Image - {} in {}".format(i, cur_label))
        
        # leer la ruta de las imágenes
        image = cv2.imread(file)
        # denotación de imágenes
        output = remove(image)
        # guardamos las imagenes

        save_path = '/content/MyDrive/MyDrive/Ai Espe/Data/Faces/Sin_Fondo/'+ cur_label
        cv2.imwrite((save_path +'/' + cur_label + str(i)+ '.jpg'), output)
        i+=1

# %%
# importo librerias 
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import tensorflow_datasets as tfds

# %%
# establesco el batch size 
batch_size = 50
img_height = 227
img_width = 227

# %%
# creacion de data sets 
train_ds = tf.keras.utils.image_dataset_from_directory(
  DG_folder,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3120 files belonging to 26 classes.
# Using 2496 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  DG_folder,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3120 files belonging to 26 classes.
# Using 624 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Ariel Chabla', 'ArroboMercy', 'BarraganSteven', 'CevallosJoan', 'EnriquezSelena', 'GenesisHeredia', 'GoyesAnthony', 'Hector Cedeño', 'Jhon Zambrano', 'Jordan Espinosa', 'Jorge Borrero', 'JoseRuiz', 'LeonardoBorja', 'LucioCarlos', 'MasacheFernando', 'MelanyLópez', 'MosqueraLucy', 'Nataly Acosta', 'OlallaLuis', 'PauteKevin', 'PárragaMaríaJosé', 'Raymond Dávila', 'RivasSelena', 'SalazarJohana', 'Solano Wilmer', 'SolórzanoBryan']

# %%
import matplotlib.pyplot as plt
# muestra un previa de el dataset de entrenamiento 
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (50, 227, 227, 3)
# (50,)

# %%
normalization_layer = tf.keras.layers.Rescaling(1./255)

# %%
normalization_layer = tf.keras.layers.Rescaling(1./255)
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 0.8481128

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
num_classes = 26

model = tf.keras.Sequential([
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(num_classes)
])

# %%
num_classes = 26
model_AlexNet = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(filters=96, kernel_size=(11,11), strides=(4,4), activation='relu', input_shape=(227,227,3)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    tf.keras.layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    tf.keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(4096, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(4096, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

# %%
model_AlexNet.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])
model_AlexNet.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_5 (Conv2D)           (None, 55, 55, 96)        34944
#
#  batch_normalization_5 (Batc  (None, 55, 55, 96)       384
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 27, 27, 96)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 27, 27, 256)       614656
#
#  batch_normalization_6 (Batc  (None, 27, 27, 256)      1024
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 13, 13, 256)      0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 13, 13, 384)       885120
#
#  batch_normalization_7 (Batc  (None, 13, 13, 384)      1536
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, 13, 13, 384)       1327488
#
#  batch_normalization_8 (Batc  (None, 13, 13, 384)      1536
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, 13, 13, 256)       884992
#
# ...
